# %% [markdown]
# # 日志分析与可视化分析
# # Simulation Run Log Analysis and Visualization for AWS DeepRacer
#
# ##### 代码来源于DeepRacer Community ( code source from DeepRacer Community):
# - https://github.com/aws-deepracer-community/aws-deepracer-workshops/blob/master/log-analysis/
#
# ##### 本笔记本介绍如何使用 AWS DeepRacer 模拟日志进行分析和调试
# 1. 查找模型最佳迭代的工具
# 1. 可视化赛道上的奖励分配
#  - 可视化每个片段或迭代的奖励热图
# 1. 为您的模型识别赛道上的热点
# 1. 了解模拟图像上的概率分布
# 1. 评估运行分析 - 绘制圈速热图
#
# This notebook walks through how you can analyze and debug using the AWS DeepRacer Simulation logs
#
#
# 1. Tools to find best iteration of your model
# 1. Visualize reward distribution on the track
#  - Visualize reward heatmap per episode or iteration
# 1. Identify hotspots on the track for your model
# 1. Understand probability distributions on simulated images
# 1. Evaluation run analysis - plot lap speed heatmap

# %% [markdown]
# ## 要求/Requirements
# boto3 >= 1.9.133; 配置 aws-cli 和/或 aws python sdk boto3 的密钥
#
# boto 3>= 1.9.133; configure your aws cli and/or boto credentials file
#
# AWS CLI: https://docs.aws.amazon.com/cli/latest/userguide/cli-chap-configure.html
#
# Boto Configuration: https://boto3.amazonaws.com/v1/documentation/api/latest/guide/configuration.html

# %% [markdown]
# ### IAM 权限/IAM permissions
# 为执行该笔记本的SageMaker notebook分配一个可以访问DeepRacer服务权限的角色。通常策略里包含”deepracer:*"权限。
#
# Assign your Sagemaker notebook an execution role with permission to access the deepracer service. Typically this is done by providing "deepracer:*" permissions.

# %%
# 导入可能使用到的python 库
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import boto3
import shutil
import os
import glob
import math
import tarfile
import requests
import json
# %matplotlib inline
from os import listdir
from os.path import isfile, join

# %%
# 安装shapeley
# !pip install shapely
# Out:
# Requirement already satisfied: shapely in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (1.8.1)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/tensorflow_p36/bin/python -m pip install --upgrade pip' command.

# %%
#Shapely Library
from shapely.geometry import Point, Polygon
from shapely.geometry.polygon import LinearRing, LineString

# %%
from log_analysis import *
from os import listdir
from os.path import isfile, join

# %%
# Ignore deprecation warnings we have no power over
# 忽略我们无法控制的弃用警告，让输出更干净一些
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 训练任务是在AWS DeepRacer管理控制台运行的，通过提供模型名称，下载需要分析的日志
# Jobs run from AWS DeepRacer Console. Download the desired log file by providing model name

# %%
# 设置模型名称，改成你的模型
# Change to your model
model_name="22-4m3-10d7-full-manual-speed-5hrs" 

# 如果你想分析评估（Evaluation）阶段的日志，设置成 False
# Make this False if you want to do log analysis on Evaluation.
is_training = True

# %%
# 清理之前的临时文件或上次分析时下载的旧数据
# Clean useless files before download new data
# !rm -rf ./tmp
# !rm -rf ./intermediate_checkpoint
# !rm -rf ./downloaded_model

# %%
envroot = os.getcwd()
aws_data_path = set(os.environ.get('AWS_DATA_PATH', '').split(os.pathsep))
aws_data_path.add(os.path.join(envroot, 'models'))
os.environ.update({'AWS_DATA_PATH': os.pathsep.join(aws_data_path)})

region = "us-east-1"
dr_client = boto3.client('deepracer', region_name=region,
        endpoint_url="https://deepracer-prod.{}.amazonaws.com".format(region))
models = dr_client.list_models(ModelType="REINFORCEMENT_LEARNING",MaxResults=100)["Models"]
for model in models:
    if model["ModelName"]==model_name:
        break
ModelArn=model["ModelArn"]

# %%
# 根据任务需要，获取训练日志或评估日志
if is_training:
    training_job=dr_client.list_training_jobs(ModelArn=ModelArn,MaxResults=100)["TrainingJobs"][0]
    training_log_url= dr_client.get_asset_url(Arn=training_job['JobArn'], AssetType="LOGS")['Url']

    with requests.get(training_log_url, stream=True) as response:
        with open("{}.tar.gz".format(model_name), "wb") as tarball:
            for chunk in response.iter_content(16384):
                tarball.write(chunk)
else:       
    evaluation_job = dr_client.list_evaluations(ModelArn=ModelArn,MaxResults=100)["EvaluationJobs"][0]
    evaluation_log_url= dr_client.get_asset_url(Arn=evaluation_job['JobArn'], AssetType="LOGS")['Url']

    with requests.get(evaluation_log_url, stream=True) as response:
        with open("{}.tar.gz".format(model_name), "wb") as tarball:
            for chunk in response.iter_content(16384):
                tarball.write(chunk)

# %%
# 获取模型ID
ModelUuid=ModelArn[ModelArn.rfind('/')+1:]
simtrace_path = "./downloaded_model/{}/sim-trace/training/training-simtrace/".format(ModelUuid)
if not is_training:
    simtrace_path = "./downloaded_model/{}/sim-trace/evaluation/*/evaluation-simtrace/".format(ModelUuid)
merged_simtrace_path = "./logs/deepracer-{}.csv".format(model_name)

# %%
# !mkdir -p downloaded_model/{ModelUuid}
# !mkdir -p intermediate_checkpoint/{ModelUuid}/model-artifacts

# !tar -xf {model_name}.tar.gz -C ./downloaded_model/
# !mkdir -p ./tmp
# !rsync -a --delete --include=*.csv --exclude=* {simtrace_path} ./tmp/
# !rm -rf downloaded_model/{model_name}
# !rm -rf {model_name}.tar.gz

# %%
model_url=dr_client.get_asset_url(Arn=model["ModelArn"],AssetType="COMPLETE_MODEL_ARTIFACT")['Url']
    
with requests.get(model_url, stream=True) as response:
    with open("{}-model.tar.gz".format(model_name), "wb") as tarball:
        for chunk in response.iter_content(16384):
            tarball.write(chunk)

# !tar zxvf {model_name}-model.tar.gz -C intermediate_checkpoint/ \*.csv {ModelUuid}/model/* {ModelUuid}/metrics/*
# !rm -rf {model_name}-model.tar.gz
# Out:
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/metrics/evaluation/evaluation-20220404012920-DC_Wb94DQT6ya85qjWSabA.json
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/metrics/training/training-20220403141941-UcBiWvuSTLqws7yJDT-MrA.json
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/model/96_Step-129658.ckpt.data-00000-of-00001
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/model/96_Step-129658.ckpt.index
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/model/96_Step-129658.ckpt.meta
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/model/model_96.pb
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/model/model_97.pb
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/model/model_98.pb
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/model/model_99.pb
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/model/model_metadata.json
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/evaluation/20220404012920-DC_Wb94DQT6ya85qjWSabA/evaluation-simtrace/0-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/0-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/1-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/10-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/11-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/12-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/13-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/14-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/15-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/16-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/17-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/18-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/19-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/2-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/20-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/21-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/22-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/23-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/24-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/25-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/26-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/27-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/28-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/29-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/3-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/30-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/31-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/32-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/33-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/34-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/35-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/36-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/37-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/38-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/39-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/4-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/40-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/41-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/42-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/43-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/44-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/45-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/46-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/47-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/48-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/49-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/5-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/50-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/51-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/52-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/53-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/54-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/55-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/56-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/57-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/58-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/59-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/6-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/60-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/61-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/62-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/63-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/64-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/65-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/66-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/67-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/68-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/69-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/7-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/70-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/71-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/72-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/73-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/74-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/75-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/76-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/77-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/78-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/79-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/8-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/80-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/81-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/82-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/83-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/84-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/85-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/86-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/87-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/88-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/89-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/9-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/90-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/91-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/92-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/93-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/94-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/95-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/96-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/97-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/sim-trace/training/training-simtrace/98-iteration.csv
# 044eac5b-477b-40f2-b6d5-b6a7c6567bda/model/.coach_checkpoint

# %%
model_url= dr_client.get_asset_url(Arn=model["ModelArn"], AssetType="MODEL_ARTIFACT")['Url']

with requests.get(model_url, stream=True) as response:
    with open("{}-model-artifacts.tar.gz".format(model_name), "wb") as tarball:
        for chunk in response.iter_content(16384):
            tarball.write(chunk)

# !tar zxvf {model_name}-model-artifacts.tar.gz -C intermediate_checkpoint/{ModelUuid}/model-artifacts
# !rm -rf {model_name}-model-artifacts.tar.gz
# Out:
# worker_0.multi_agent_graph.main_level.main_level.agent_0.csv
# worker_0.multi_agent_graph_0.json
# model_metadata.json
# agent/
# agent/model.pb

# %% [markdown]
# 查看此次训练的元数据，包括：行动空间，传感器类型，神经网络，训练算法，行动空间类别。

# %%
with open("intermediate_checkpoint/{}/model/model_metadata.json".format(ModelUuid),"r") as jsonin:
    model_metadata=json.load(jsonin)
sensor = [sensor for sensor in model_metadata['sensor'] if sensor != "LIDAR"][0]
model_metadata
# Out:
# {'action_space': [{'steering_angle': -10.0,
#    'speed': 1.3333333333333333,
#    'index': 0},
#   {'steering_angle': -10.0, 'speed': 2.6666666666666665, 'index': 1},
#   {'steering_angle': -10.0, 'speed': 4.0, 'index': 2},
#   {'steering_angle': -6.666666666666668,
#    'speed': 1.3333333333333333,
#    'index': 3},
#   {'steering_angle': -6.666666666666668,
#    'speed': 2.6666666666666665,
#    'index': 4},
#   {'steering_angle': -6.666666666666668, 'speed': 4.0, 'index': 5},
#   {'steering_angle': -3.333333333333335,
#    'speed': 1.3333333333333333,
#    'index': 6},
#   {'steering_angle': -3.333333333333335,
#    'speed': 2.6666666666666665,
#    'index': 7},
#   {'steering_angle': -3.333333333333335, 'speed': 4.0, 'index': 8},
#   {'steering_angle': 0.0, 'speed': 1.3333333333333333, 'index': 9},
#   {'steering_angle': 0.0, 'speed': 2.6666666666666665, 'index': 10},
#   {'steering_angle': 0.0, 'speed': 4.0, 'index': 11},
#   {'steering_angle': 3.333333333333332,
#    'speed': 1.3333333333333333,
#    'index': 12},
#   {'steering_angle': 3.333333333333332,
#    'speed': 2.6666666666666665,
#    'index': 13},
#   {'steering_angle': 3.333333333333332, 'speed': 4.0, 'index': 14},
#   {'steering_angle': 6.666666666666668,
#    'speed': 1.3333333333333333,
#    'index': 15},
#   {'steering_angle': 6.666666666666668,
#    'speed': 2.6666666666666665,
#    'index': 16},
#   {'steering_angle': 6.666666666666668, 'speed': 4.0, 'index': 17},
#   {'steering_angle': 10.0, 'speed': 1.3333333333333333, 'index': 18},
#   {'steering_angle': 10.0, 'speed': 2.6666666666666665, 'index': 19},
#   {'steering_angle': 10.0, 'speed': 4.0, 'index': 20}],
#  'sensor': ['FRONT_FACING_CAMERA'],
#  'neural_network': 'DEEP_CONVOLUTIONAL_NETWORK_SHALLOW',
#  'version': '5',
#  'training_algorithm': 'clipped_ppo',
#  'action_space_type': 'discrete'}

# %% [markdown]
# ## 下载对应的日志
#
# Download the desired log file given the simulation ID
# Merge all the csv files into one big .csv file

# %%
def get_sort_csv_file():
    sim_trace_csvs = glob.glob("./tmp/*.csv")
    csvs_with_ids = [(int(os.path.basename(file).split("-")[0]), file) for file in sim_trace_csvs]
    csvs_sorted = sorted(csvs_with_ids, key=lambda csvs_with_ids: csvs_with_ids[0])
    return [csv_file[1] for csv_file in csvs_sorted]

# 将所有的日志合并至一个文件
def merge_csv_files(output_file_path):
    csv_files = get_sort_csv_file()
    header_saved = False
    with open(output_file_path, 'w') as fout:
        for csv_file in csv_files:
            with open(csv_file) as fin:
                header = next(fin)
                if not header_saved:
                    fout.write(header)
                    header_saved = True
                for line in fin:
                    line = re.sub(r'(\[[^\]]*\])', r'"\1"', line, flags=re.M)
                    fout.write(line)

merge_csv_files(merged_simtrace_path)
# !tail -n 3 $merged_simtrace_path
# Out:
# 1979,101.0,4.832261400619767,0.9203082588392081,92.10130820810176,0.0,2.6666666666666665,10,0.001,False,False,32.03684858363141,43,48.06927451701628,14857.489,in_progress,0.0
# 1979,102.0,4.835545227071812,1.1157350754051805,90.08103400345833,-10.0,1.3333333333333333,0,0.001,False,False,32.09993258293436,44,48.06927451701628,14857.547,in_progress,0.0
# 1979,103.0,4.848060489506666,1.2686083119182918,87.47397406908739,6.666666666666668,4.0,17,0.001,True,False,32.31127582999716,44,48.06927451701628,14857.618,off_track,0.0

# %% [markdown]
# ## 辅助函数 Helper Functions

# %%
def plot_points(ax, points):
    ax.scatter(points[:-1,0], points[:-1,1], s=3, c='red')
    for i,p in enumerate(points):
        if i%10 ==0:
            ax.annotate(i, (p[0], p[1]))

def plot_coords(ax, ob):                                                        
    x, y = ob.xy                                                                
    ax.plot(x, y, '.', color='lightgray', zorder=1)                               
                                                                                
def plot_bounds(ax, ob):                                                        
    x, y = zip(*list((p.x, p.y) for p in ob.boundary))                          
    ax.plot(x, y, '.', color='white', zorder=1)                               
                                                                                
def plot_line(ax, ob, color='green'):                                                          
    x, y = ob.xy
    ax.plot(x, y, alpha=0.7, color=color, linewidth=3, solid_capstyle='round', zorder=2)

def print_border(ax, waypoints, inner_border_waypoints, outer_border_waypoints):
    line = LineString(waypoints)                                                
    plot_line(ax, line, color='lightgreen')                                                         
                                                                                
    line = LineString(inner_border_waypoints)                                   
    plot_coords(ax, line)                                                       
    plot_line(ax, line)                                                         
                                                                                
    line = LineString(outer_border_waypoints)                                   
    plot_coords(ax, line)                                                       
    plot_line(ax, line)

# 画出完成赛道最快的n圈
# plot top n completed laps
def plot_top_laps(sorted_idx, n_laps=5):
    fig = plt.figure(n_laps, figsize=(12, 30))
    for i in range(n_laps):
        idx = sorted_idx[i]
        
        episode_data = episode_map[idx]
        
        ax = fig.add_subplot(n_laps,1,i+1)
        
        line = LineString(center_line)
        plot_coords(ax, line)
        plot_line(ax, line)
        
        line = LineString(inner_border)
        plot_coords(ax, line)
        plot_line(ax, line)

        line = LineString(outer_border)
        plot_coords(ax, line)
        plot_line(ax, line)


        for idx in range(1, len(episode_data)-1):
            x1,y1,action,reward,angle,speed = episode_data[idx]
            car_x2, car_y2 = x1 - 0.02, y1
            plt.plot([x1, car_x2], [y1, car_y2], 'b.')
    return fig

# %%
#选择赛道
TRACK_NAME = '2022_march_open'

#导入赛道路点
waypoints = np.load("./tracks/%s.npy" % TRACK_NAME)
center_line = waypoints[:,0:2]
inner_border = waypoints[:,2:4]
outer_border = waypoints[:,4:6]

#导入最佳行车线，最佳速度图
fpath = f'./racelines/optimals_newest_{TRACK_NAME}.npy'
raceline = np.load(fpath)

# %%
merged_simtrace_path
# Out:
# './logs/deepracer-22-4m3-10d7-full-manual-speed-5hrs.csv'

# %%
EPISODE_PER_ITER = 20 if is_training else 1

df = pd.read_csv(merged_simtrace_path)
iteration_arr = np.arange(math.ceil(df.episode.max()/EPISODE_PER_ITER)+1) * EPISODE_PER_ITER
df['iteration'] = np.digitize(df.episode, iteration_arr)
df = df.rename(columns={"X": "x", "Y": "y", "tstamp": "timestamp"})
df.head()
# Out:
#    episode  steps         x         y       yaw      steer  throttle  action  \
# 0        0    1.0 -1.898400 -5.964726 -8.775405   6.666667  2.666667      16
# 1        0    2.0 -1.898574 -5.964691 -8.773750   6.666667  1.333333      15
# 2        0    3.0 -1.891434 -5.968319 -9.410424  10.000000  2.666667      19
# 3        0    4.0 -1.868685 -5.970415 -8.979991 -10.000000  2.666667       1
# 4        0    5.0 -1.837003 -5.977752 -9.602920   6.666667  2.666667      16
#
#    reward   done  all_wheels_on_track  progress  closest_waypoint  track_len  \
# 0   0.000  False                 True  0.291615                 0  48.069275
# 1   0.001  False                 True  0.291246                 0  48.069275
# 2   0.001  False                 True  0.307078                 0  48.069275
# 3   0.001  False                 True  0.354513                 1  48.069275
# 4   0.001  False                 True  0.421980                 1  48.069275
#
#    timestamp episode_status  pause_duration  iteration
# 0     21.473        prepare             0.0          1
# 1     21.541    in_progress             0.0          1
# 2     21.598    in_progress             0.0          1
# 3     21.668    in_progress             0.0          1
# 4     21.736    in_progress             0.0          1

# %%
def plot_top_laps_to_raceline(sorted_idx, n_laps=5):
    fig = plt.figure(n_laps, figsize=(12, 30))
    for i in range(n_laps):
        idx = sorted_idx[i]
        
        episode_data = episode_map[idx]
        
        ax = fig.add_subplot(n_laps,1,i+1)
        
        #line = LineString(center_line)
        #plot_coords(ax, line)
        #plot_line(ax, line)
        
        line = LineString(inner_border)
        plot_coords(ax, line)
        #plot_line(ax, line)

        line = LineString(outer_border)
        plot_coords(ax, line)
        #plot_line(ax, line)
        
        x1=[i[0] for i in episode_data]
        y1=[i[1] for i in episode_data]
        speed=[i[5] for i in episode_data]
        #for idx in range(1, len(episode_data)-1):
        #    x1,y1,action,reward,angle,speed = episode_data[idx]
        #    car_x2, car_y2 = x1 - 0.02, y1
        #for idx in range(1, len(racing_track)-1):
        #    plt.plot(racing_track[idx][0],racing_track[idx][1],hue=racing_track[idx][2], palette="vlag")
        sns.scatterplot(x=x1, y=y1, hue=speed, palette="Greens")
        
        # optimal raceline
        x1=[i[0] for i in raceline]
        y1=[i[1] for i in raceline]
        speed=[i[2] for i in raceline]
        sns.scatterplot(x=x1, y=y1, hue=speed, palette="Reds")
       
    plt.show()
    return fig

# %%
action_map, episode_map, sorted_idx = episode_parser(df)
print("The top 3 highest reward episodes are {}".format(sorted_idx[:3]))
fig = plot_top_laps_to_raceline(sorted_idx[:], 3)
# Out:
# The top 3 highest reward episodes are [1788, 1115, 1298]

# %% [markdown]
# ### 画出每个片段赛车的行车线

# %%
## Evaluation RUN
def plot_episode_run(df, E):
    fig = plt.figure(1, figsize=(12, 16))
    ax = fig.add_subplot(211)
    plt.axis('equal')
    print_border(ax, center_line, inner_border, outer_border) 
    episode_data = df[df['episode'] == E]
    for row in episode_data.iterrows():
        x1,y1,action,reward = row[1]['x'], row[1]['y'], row[1]['action'], row[1]['reward']
        car_x2, car_y2 = x1 - 0.02, y1
        plt.plot([x1, car_x2], [y1, car_y2], 'r.')

# %%
#iteration_id = 1

for iteration_id in range(1,2):#max(df["iteration"]+1)) :
    for i in range((iteration_id-1)*EPISODE_PER_ITER, (iteration_id)*EPISODE_PER_ITER):
        plot_episode_run(df, E=i)

# %% [markdown]
# ### 画出完成赛道的行车线

# %%
## Evaluation Completed Laps
def plot_episode_complete(df):
    fig = plt.figure(1, figsize=(12, 16))
    ax = fig.add_subplot(211)
    plt.axis('equal')
    print_border(ax, center_line, inner_border, outer_border) 
    for row in df.iterrows():
        x1,y1,action,reward = row[1]['x'], row[1]['y'], row[1]['action'], row[1]['reward']
        car_x2, car_y2 = x1 - 0.02, y1
        plt.plot([x1, car_x2], [y1, car_y2],'r.')

# %%
df_complete_episode = pd.DataFrame(columns = ['episode', 'steps', 'x', 'y', 'yaw', 'steer', 'throttle', 'action',
       'reward', 'done', 'all_wheels_on_track', 'progress', 'closest_waypoint',
       'track_len', 'timestamp', 'episode_status', 'pause_duration',
       'iteration'])
df_complete_episode_i = df[df["progress"] == 100]["episode"]

for i in df_complete_episode_i:
    df_i = df[df["episode"]==i]
    #df_complete_episode.append(df_i,ignore_index=True)
    df_complete_episode = pd.concat([df_complete_episode,df_i])

print(f"Total completed laps are:",len(df_complete_episode_i))
plot_episode_complete(df_complete_episode)
# Out:
# Total completed laps are: 4

# %% [markdown]
# ## 赛车的视角 View of the model/agent

# %%
import cv2
import numpy as np
import tensorflow as tf


def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

def visualize_gradcam_discrete_ppo(sess, rgb_img, category_index=0, num_of_actions=5):
    '''
    @inp: model session, RGB Image - np array, action_index, total number of actions 
    @return: overlayed heatmap
    '''
    
    img_arr = np.array(img)
    img_arr = rgb2gray(img_arr)
    img_arr = np.expand_dims(img_arr, axis=2)
    
    x = sess.graph.get_tensor_by_name('main_level/agent/main/online/network_0/{}/{}:0'.format(sensor, sensor))
    y = sess.graph.get_tensor_by_name('main_level/agent/main/online/network_1/ppo_head_0/policy:0')
    feed_dict = {x:[img_arr]}

    #Get he policy head for clipped ppo in coach
    model_out_layer = sess.graph.get_tensor_by_name('main_level/agent/main/online/network_1/ppo_head_0/policy:0')
    loss = tf.multiply(model_out_layer, tf.one_hot([category_index], num_of_actions))
    reduced_loss = tf.reduce_sum(loss[0])
    
    # For front cameras use the below
    conv_output = sess.graph.get_tensor_by_name('main_level/agent/main/online/network_1/{}/Conv2d_4/Conv2D:0'.format(sensor))
    
    grads = tf.gradients(reduced_loss, conv_output)[0]
    output, grads_val = sess.run([conv_output, grads], feed_dict=feed_dict)
    weights = np.mean(grads_val, axis=(1, 2))
    cams = np.sum(weights * output, axis=3)

    ##im_h, im_w = 120, 160##
    im_h, im_w = rgb_img.shape[:2]

    cam = cams[0] #img 0
    image = np.uint8(rgb_img[:, :, ::-1] * 255.0) # RGB -> BGR
    cam = cv2.resize(cam, (im_w, im_h)) # zoom heatmap
    cam = np.maximum(cam, 0) # relu clip
    heatmap = cam / np.max(cam) # normalize
    cam = cv2.applyColorMap(np.uint8(255 * heatmap), cv2.COLORMAP_JET) # grayscale to color
    cam = np.float32(cam) + np.float32(image) # overlay heatmap
    cam = 255 * cam / (np.max(cam) + 1E-5) ##  Add expsilon for stability
    cam = np.uint8(cam)[:, :, ::-1] # to RGB

    return cam
# Out:
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/cpu/lib/python3.6/site-packages/tensorflow_core/__init__.py:1473: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.

# %%
import glob
img_path = "simulation_episode/"
all_files = sorted(glob.glob(img_path + '/*.png'))

import tensorflow as tf
import numpy as np
from tensorflow.python.platform import gfile
from PIL import Image

GRAPH_PB_PATH = 'intermediate_checkpoint/'
models_file_path = glob.glob("{}{}/model/model_*.pb".format(GRAPH_PB_PATH, ModelUuid))

# %%
def load_session(pb_path):
    sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True, 
                                    log_device_placement=True))
    print("load graph:", pb_path)
    with gfile.FastGFile(pb_path,'rb') as f:
        graph_def = tf.GraphDef()
    graph_def.ParseFromString(f.read())
    sess.graph.as_default()
    tf.import_graph_def(graph_def, name='')
    graph_nodes=[n for n in graph_def.node]
    names = []
    for t in graph_nodes:
        names.append(t.name)
    
    # For front cameras/stereo camera use the below
    x = sess.graph.get_tensor_by_name('main_level/agent/main/online/network_0/{}/{}:0'.format(sensor, sensor))
    y = sess.graph.get_tensor_by_name('main_level/agent/main/online/network_1/ppo_head_0/policy:0')
    
    return sess, x, y

# %%
action_names = []
for action in model_metadata['action_space']:
    action_names.append("ST"+str(action['steering_angle'])+" SP"+"%.2f"%action["speed"])

# %%
model_path = models_file_path[0] #Change this to your model 'pb' frozen graph file

model, obs, model_out = load_session(model_path)
heatmaps = []

#Just need to match up the shape of the neural network
if 'action_space_type' in model_metadata and model_metadata['action_space_type']=='continuous':
    num_of_actions=2
else:
    num_of_actions=len(action_names)

for f in all_files[:3]:
    img = np.array(Image.open(f))
    heatmap = visualize_gradcam_discrete_ppo(model, img, category_index=0, num_of_actions=num_of_actions)
    heatmaps.append(heatmap)
tf.reset_default_graph()
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
#
# load graph: intermediate_checkpoint/044eac5b-477b-40f2-b6d5-b6a7c6567bda/model/model_98.pb
# WARNING:tensorflow:From <ipython-input-32-e45fcbcfe835>:5: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.

# %%
for i in range(len(heatmaps)):
    plt.imshow(heatmaps[i])
    plt.show()
